# %% [markdown]
# # Synthetic Time Series Example
# This notebook contains a simple example of generating a simple synthetic time series. This time series has the following structure:
# - A base shape of a sine curve with additive noise.
# - The possibility to include trend events.
# - The possibility to include cosine events, where a cosine curve overlaps the sine curve.
# - The possibility to include events with an increased amount of noise.

# %%
import numpy as np

from synthetictime.simple_time_series import SimpleTimeSeries

# %%
# First we set a random seed
np.random.seed(7)
# Now we initiate a simple time series object with the desired parameters
# This also automatically generates the time series
example_series = SimpleTimeSeries(size=100,
                                  base_amplitude=5.0,
                                  base_frequency=0.05,
                                  base_noise_scale=1,
                                  base_noise_amplitude=1,
                                  number_of_trend_events=2,
                                  trend_slope_low=0.01,
                                  trend_slope_high=0.2,
                                  number_of_cosine_events =3,
                                  cosine_frequency_low=0.01,
                                  cosine_frequency_high=0.2,
                                  cosine_amplitude_low=2.0,
                                  cosine_amplitude_high=8,
                                  number_of_increased_noise_events=2,
                                  increased_noise_low=0.8,
                                  increased_noise_high=2,
                                  noise_type="additive")

# %%
# Finally we plot the time series and the components making up the time series.
example_series.plot_time_series()
